# %%
import polars as pl

# %%
base_dir = "/Users/zhangyubo/Projects/QuantData/Ashare/"

# %%
df = pl.read_parquet("base_dir/stock_info/finance_capital/000001_SZ_cap.parquet")

# %%
df
# Out:
# shape: (181, 7)
# ┌───────────┬───────────┬───────────────┬───────────────┬───────────────┬──────────────┬───────────┐
# │ m_timetag ┆ m_anntime ┆ total_capital ┆ circulating_c ┆ restrict_circ ┆ freeFloatCap ┆ m_quarter │
# │ ---       ┆ ---       ┆ ---           ┆ apital        ┆ ulating_capit ┆ ital         ┆ ---       │
# │ str       ┆ str       ┆ f64           ┆ ---           ┆ al            ┆ ---          ┆ f64       │
# │           ┆           ┆               ┆ f64           ┆ ---           ┆ f64          ┆           │
# │           ┆           ┆               ┆               ┆ f64           ┆              ┆           │
# ╞═══════════╪═══════════╪═══════════════╪═══════════════╪═══════════════╪══════════════╪═══════════╡
# │ 19910403  ┆ 19910403  ┆ 4.8500171e7   ┆ 2.65e7        ┆ 0.0           ┆ 0.0          ┆ 0.0       │
# │ 19910630  ┆ 19910630  ┆ 4.8500171e7   ┆ 2.65e7        ┆ 0.0           ┆ 0.0          ┆ 0.0       │
# ...

# %%
df2 = pl.read_parquet(f"{base_dir}/stock_day/600004_SH.parquet")

# %%
df2
# Out:
# shape: (1_434, 8)
# ┌───────────────┬────────┬────────┬────────┬────────┬────────┬──────────────┬─────────────┐
# │ time          ┆ open   ┆ high   ┆ low    ┆ close  ┆ volume ┆ amount       ┆ suspendFlag │
# │ ---           ┆ ---    ┆ ---    ┆ ---    ┆ ---    ┆ ---    ┆ ---          ┆ ---         │
# │ i64           ┆ f64    ┆ f64    ┆ f64    ┆ f64    ┆ i64    ┆ f64          ┆ i32         │
# ╞═══════════════╪════════╪════════╪════════╪════════╪════════╪══════════════╪═════════════╡
# │ 1577894400000 ┆ 17.141 ┆ 17.201 ┆ 16.981 ┆ 17.101 ┆ 177924 ┆ 3.11394028e8 ┆ 0           │
# │ 1577980800000 ┆ 17.191 ┆ 17.201 ┆ 16.891 ┆ 16.961 ┆ 163146 ┆ 2.84126626e8 ┆ 0           │
# │ 1578240000000 ┆ 16.821 ┆ 16.821 ┆ 16.531 ┆ 16.661 ┆ 214553 ┆ 3.6601e8     ┆ 0           │
# │ 1578326400000 ┆ 16.641 ┆ 16.871 ┆ 16.481 ┆ 16.841 ┆ 168007 ┆ 2.872421e8   ┆ 0           │
# │ 1578412800000 ┆ 16.791 ┆ 16.911 ┆ 16.531 ┆ 16.671 ┆ 166815 ┆ 2.8496e8     ┆ 0           │
# ...
